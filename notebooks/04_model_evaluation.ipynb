# %% [markdown]
# # Model Evaluation
#
# This notebook evaluates detection model performance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, precision_recall_curve, confusion_matrix

# %%
# TODO: Load predictions and evaluate models
